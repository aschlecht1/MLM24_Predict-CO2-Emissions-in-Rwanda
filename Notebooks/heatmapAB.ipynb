# %% [markdown]
# # Setup & Load Data #

# %%
#Import
from pathlib import Path 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#Create paths
data_dir = Path('../Data')
code_dir = Path('../Code')

# %%
#Load Data
emission_dafta = pd.read_csv(
    data_dir / 'train.csv',
    index_col = 'ID_LAT_LON_YEAR_WEEK',)

#Print Data
emission_data["location"] = emission_data["latitude"].astype(str)+ "_" + emission_data["longitude"].astype(str)
emission_data
# Out:
#                           latitude  longitude  year  week_no  \
# ID_LAT_LON_YEAR_WEEK
# ID_-0.510_29.290_2019_00    -0.510     29.290  2019        0
# ID_-0.510_29.290_2019_01    -0.510     29.290  2019        1
# ID_-0.510_29.290_2019_02    -0.510     29.290  2019        2
# ID_-0.510_29.290_2019_03    -0.510     29.290  2019        3
# ID_-0.510_29.290_2019_04    -0.510     29.290  2019        4
# ...                            ...        ...   ...      ...
# ID_-3.299_30.301_2021_48    -3.299     30.301  2021       48
# ID_-3.299_30.301_2021_49    -3.299     30.301  2021       49
# ID_-3.299_30.301_2021_50    -3.299     30.301  2021       50
# ID_-3.299_30.301_2021_51    -3.299     30.301  2021       51
# ID_-3.299_30.301_2021_52    -3.299     30.301  2021       52
#
#                           SulphurDioxide_SO2_column_number_density  \
# ID_LAT_LON_YEAR_WEEK
# ID_-0.510_29.290_2019_00                                 -0.000108
# ...

# %%
#Group By Location
#https://pandas.pydata.org/pandas-docs/stable/reference/groupby.html#computations-descriptive-stats
#take note that some sites never report any emissions
emission_sites = emission_data.groupby(['location']).emission.agg(['mean','median', 'min', 'max','std','count'])
emission_sites
# Out:
#                      mean      median        min         max       std  count
# location
# -0.51_29.29      4.272966    4.327319   2.822296    4.873383  0.386600    159
# -0.528_29.472    4.183500    4.247256   2.586009    4.770357  0.446894    159
# -0.547_29.653    0.589954    0.594541   0.408448    0.695020  0.057129    159
# -0.569_30.031  116.187763  114.997185  90.212845  137.518830  9.784380    159
# -0.598_29.102    0.090357    0.091131   0.062813    0.106363  0.008712    159
# ...                   ...         ...        ...         ...       ...    ...
# -3.153_30.347   14.502592   15.005790   7.657632   17.818768  2.358194    159
# -3.161_28.839    0.125809    0.126787   0.087101    0.148215  0.012183    159
# -3.174_29.926   44.832340   45.602253  32.883167   51.459305  3.743186    159
# -3.287_29.713   42.077684   42.520153  25.492178   49.119910  4.875839    159
# -3.299_30.301   27.633301   28.150387  18.609112   32.293903  2.752694    159
#
# [497 rows x 6 columns]

# %%
#Write to Disk
#emission_sites.to_csv(data_dir / 'emission_sites.csv')

# %%
#Merge data together

# %%
merged_data = pd.merge(emission_data,emission_sites,on="location")
merged_data
# Out:
#        latitude  longitude  year  week_no  \
# 0        -0.510     29.290  2019        0
# 1        -0.510     29.290  2019        1
# 2        -0.510     29.290  2019        2
# 3        -0.510     29.290  2019        3
# 4        -0.510     29.290  2019        4
# ...         ...        ...   ...      ...
# 79018    -3.299     30.301  2021       48
# 79019    -3.299     30.301  2021       49
# 79020    -3.299     30.301  2021       50
# 79021    -3.299     30.301  2021       51
# 79022    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# 2                                      0.000514
# 3                                           NaN
# 4                                     -0.000079
# ...                                         ...
# 79018                                  0.000284
# 79019                                  0.000083
# ...

# %%
#scale emission for heat map: (emission - mean) / std

# %%
merged_data["scaled_emission"] = (merged_data["emission"] - merged_data["mean"]) / merged_data["std"]
merged_data["fulldate"] = merged_data["year"].astype(str) + "_" + merged_data["week_no"].astype(str).apply('{:0>2}'.format)
merged_data
# Out:
#        latitude  longitude  year  week_no  \
# 0        -0.510     29.290  2019        0
# 1        -0.510     29.290  2019        1
# 2        -0.510     29.290  2019        2
# 3        -0.510     29.290  2019        3
# 4        -0.510     29.290  2019        4
# ...         ...        ...   ...      ...
# 79018    -3.299     30.301  2021       48
# 79019    -3.299     30.301  2021       49
# 79020    -3.299     30.301  2021       50
# 79021    -3.299     30.301  2021       51
# 79022    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# 2                                      0.000514
# 3                                           NaN
# 4                                     -0.000079
# ...                                         ...
# 79018                                  0.000284
# 79019                                  0.000083
# ...

# %%
#Create a heatmap
merged_data_heatmap = merged_data.pivot(index="location", columns="fulldate", values="scaled_emission")
plt.subplots(figsize=(60,20))
sns.heatmap(merged_data_heatmap)
# Out:
# <Axes: xlabel='fulldate', ylabel='location'>
